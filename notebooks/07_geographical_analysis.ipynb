# %% [markdown]
# # 07 - Geographical Analysis
#
# This notebook analyzes sales patterns by country with interactive visualizations.
#
# ## Objectives
# - Aggregate sales data by country and year
# - Create interactive visualizations
# - Build dashboard with country selection
# - Analyze country-specific trends
# - Compare market performance

# %%
# Setup for Colab
from google.colab import drive
drive.mount('/content/drive')

# Install required packages
# !pip install pandas numpy matplotlib seaborn plotly
